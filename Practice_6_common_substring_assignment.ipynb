# %% [markdown]
# # Homework Assignment – Common Substring (k-mers)
#
# ## Instructions
# - Answer all questions
# - Write code only in the designated sections
# - Do not change function names
# - Run cells to test your solutions

# %% [markdown]
# ## Part 0 – Given Code

# %%
def common_substring_naive(s1, s2, k):
    ''' find a common substring of length k in both s1 and s2 '''
    for i in range(len(s1)-k+1):
        for j in range(len(s2)-k+1):
            if s1[i:i+k] == s2[j:j+k]:
                return s1[i:i+k]
    return None

# Example
print(common_substring_naive("AGGAT", "GGACGAT", 3))
# Out:
# GGA

# %% [markdown]
# ## Question 1 – Return indices

# %% [markdown]
# Modify the function so it returns:
#
# (substring, i, j)
#
# where:
# s1[i:i+k] == s2[j:j+k]

# %%
def common_substring_naive2(s1, s2, k):
    # WRITE YOUR CODE HERE
    pass

# Test
print(common_substring_naive2("AGGAT", "GGACGAT", 3))

# %% [markdown]
# ## Question 2 – Return all matches

# %% [markdown]
# Return a list of all common substrings of length k (no duplicates).

# %%
def common_substring_all_naive(s1, s2, k):
    # WRITE YOUR CODE HERE
    pass

# Tests
print(common_substring_all_naive("AGGAT", "GGACGAT", 3))
print(common_substring_all_naive("AGGAT", "GGACGAT", 4))

# %% [markdown]
# ## Question 3 – Analysis

# %% [markdown]
# Answer the following:
#
# 1. What is the time complexity of the naive algorithm?
# 2. What is the best case?
# 3. What is the worst case?
# 4. Why does the algorithm become slow when no match exists?

# %%
# Write your answers here

# %% [markdown]
# ## Hash-based solution

# %%
def common_substring_hash(s1, s2, k):
    # WRITE YOUR CODE HERE
    pass
